# %% [markdown]
# # MAIN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\chaud\Downloads\DailyDelhiClimateTest.csv")

# %%
df
# Out:
#            date   meantemp   humidity  wind_speed  meanpressure
# 0    2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1    2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2    2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3    2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4    2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ..          ...        ...        ...         ...           ...
# 109  2017-04-20  34.500000  27.500000    5.562500    998.625000
# 110  2017-04-21  34.250000  39.375000    6.962500    999.875000
# 111  2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 112  2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 113  2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 5 columns]

# %%
df = df[['date','meantemp']]
df
# Out:
#            date   meantemp
# 0    2017-01-01  15.913043
# 1    2017-01-02  18.500000
# 2    2017-01-03  17.111111
# 3    2017-01-04  18.700000
# 4    2017-01-05  18.388889
# ..          ...        ...
# 109  2017-04-20  34.500000
# 110  2017-04-21  34.250000
# 111  2017-04-22  32.900000
# 112  2017-04-23  32.875000
# 113  2017-04-24  32.000000
#
# [114 rows x 2 columns]

# %%
plt.scatter(df['date'],df['meantemp'],color = 'red')

# %%
x1 = df['meantemp'].ewm(alpha=.9).mean()

# %%
x1
# Out:
# 0      15.913043
# 1      18.264822
# 2      17.225443
# 3      18.552677
# 4      18.405266
#          ...
# 109    34.403401
# 110    34.265340
# 111    33.036534
# 112    32.891153
# 113    32.089115
# Name: meantemp, Length: 114, dtype: float64

# %%
df['ewma']=x1
df
# Out:
# C:\Users\chaud\AppData\Local\Temp\ipykernel_18896\4042715845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ewma']=x1
#            date   meantemp       ewma
# 0    2017-01-01  15.913043  15.913043
# 1    2017-01-02  18.500000  18.264822
# 2    2017-01-03  17.111111  17.225443
# 3    2017-01-04  18.700000  18.552677
# 4    2017-01-05  18.388889  18.405266
# ..          ...        ...        ...
# 109  2017-04-20  34.500000  34.403401
# 110  2017-04-21  34.250000  34.265340
# 111  2017-04-22  32.900000  33.036534
# 112  2017-04-23  32.875000  32.891153
# 113  2017-04-24  32.000000  32.089115
#
# [114 rows x 3 columns]

# %%
# plt.scatter(df['date'],['meantemp'],color='red')
plt.scatter(df['date'], df['meantemp'], color='red')

plt.plot(df['date'],x1,color='black',label = 'alpha = 0.9')
plt.legend()
plt.show()

# %% [markdown]
# # Practice

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\chaud\Downloads\EWMA\daily-minimum-temperatures-in-me.csv")
df = df.iloc[:200]

# %%
plt.scatter(df['Date'],df['Daily minimum temperatures'], color = 'red')

# %%
x2 = df['Daily minimum temperatures'].ewm(alpha=1).mean()
x2
# Out:
# 0      20.7
# 1      17.9
# 2      18.8
# 3      14.6
# 4      15.8
#        ...
# 195     7.2
# 196     6.3
# 197     8.8
# 198     5.0
# 199     7.4
# Name: Daily minimum temperatures, Length: 200, dtype: float64

# %%
df['EWMA']=x2
df
# Out:
#           Date Daily minimum temperatures  EWMA
# 0     1/1/1981                       20.7  20.7
# 1     1/2/1981                       17.9  17.9
# 2     1/3/1981                       18.8  18.8
# 3     1/4/1981                       14.6  14.6
# 4     1/5/1981                       15.8  15.8
# ..         ...                        ...   ...
# 195  7/15/1981                        7.2   7.2
# 196  7/16/1981                        6.3   6.3
# 197  7/17/1981                        8.8   8.8
# 198  7/18/1981                          5   5.0
# 199  7/19/1981                        7.4   7.4
#
# [200 rows x 3 columns]

# %%
plt.scatter(df['Date'], df['Daily minimum temperatures'], color='red')  
plt.plot(df['Date'], df['EWMA'], color='black', label='alpha = 0.9')

plt.legend()
plt.show()

# %%
plt.scatter(df['Date'], df['Daily minimum temperatures'], color='red')  
plt.plot(df['Date'], df['EWMA'], color='black', label='alpha = 0.01')

plt.legend()
plt.show()

# %%
plt.scatter(df['Date'], df['Daily minimum temperatures'], color='red')  
plt.plot(df['Date'], df['EWMA'], color='black', label='alpha = 0.1')

plt.legend()
plt.show()

# %%
plt.scatter(df['Date'], df['Daily minimum temperatures'], color='red')  
plt.plot(df['Date'], df['EWMA'], color='black', label='alpha = 1')

plt.legend()
plt.show()
